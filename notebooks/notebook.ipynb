# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.features.notebook_helpers import prepare_data

# %%
FS = 12000
WINDOW_SIZE = 2048
OVERLAP = 0.5
STEP = int(WINDOW_SIZE * (1 - OVERLAP))

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
from src.features.pipeline import build_windows

df = build_windows()
print(df['label'].value_counts())
print(df.head())
# Out:
# 24
# label
# Normal       1653
# InnerRace     472
# OuterRace     471
# Ball          469
# Name: count, dtype: int64

# %%
print(len(files))
# Out:
# 24

# %%
import numpy as np
from src.features.extract import extract_features

# %%
from src.features.pipeline import build_feature_table

features_df = build_feature_table()
features_df.head()
